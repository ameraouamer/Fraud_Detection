# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import warnings
warnings.filterwarnings('ignore')
sns.set_style('whitegrid')

# %%
df=pd.read_csv('AIML Dataset.csv')

# %%
df.head()
# Out:
#    step      type    amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 0     1   PAYMENT   9839.64  C1231006815       170136.0       160296.36
# 1     1   PAYMENT   1864.28  C1666544295        21249.0        19384.72
# 2     1  TRANSFER    181.00  C1305486145          181.0            0.00
# 3     1  CASH_OUT    181.00   C840083671          181.0            0.00
# 4     1   PAYMENT  11668.14  C2048537720        41554.0        29885.86
#
#       nameDest  oldbalanceDest  newbalanceDest  isFraud  isFlaggedFraud
# 0  M1979787155             0.0             0.0        0               0
# 1  M2044282225             0.0             0.0        0               0
# 2   C553264065             0.0             0.0        1               0
# 3    C38997010         21182.0             0.0        1               0
# 4  M1230701703             0.0             0.0        0               0

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 6362620 entries, 0 to 6362619
# Data columns (total 11 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   step            int64
#  1   type            str
#  2   amount          float64
#  3   nameOrig        str
#  4   oldbalanceOrg   float64
#  5   newbalanceOrig  float64
#  6   nameDest        str
#  7   oldbalanceDest  float64
#  8   newbalanceDest  float64
#  9   isFraud         int64
#  10  isFlaggedFraud  int64
# dtypes: float64(5), int64(3), str(3)
# memory usage: 534.0 MB

# %%
df['isFraud'].value_counts()
# Out:
# isFraud
# 0    6354407
# 1       8213
# Name: count, dtype: int64

# %%
df['isFlaggedFraud'].value_counts()
# Out:
# isFlaggedFraud
# 0    6362604
# 1         16
# Name: count, dtype: int64

# %%
df.columns
# Out:
# Index(['step', 'type', 'amount', 'nameOrig', 'oldbalanceOrg', 'newbalanceOrig',
#        'nameDest', 'oldbalanceDest', 'newbalanceDest', 'isFraud',
#        'isFlaggedFraud'],
#       dtype='str')

# %%
df.isnull().sum().sum()
# Out:
# np.int64(0)

# %%
df.shape[0]
# Out:
# 6362620

# %%
df.isFraud.value_counts()[1]
# Out:
# np.int64(8213)

# %%
df['isFraud'].value_counts()[1]/df.shape[0] *100
# Out:
# np.float64(0.12908204481801522)

# %%
df['type'].value_counts().plot(kind='bar',title='transactions type ',color='red')
plt.xlabel('type')
plt.ylabel('count')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
Fraud_by_type=df.groupby('type')['isFraud'].mean().sort_values(ascending=False)
Fraud_by_type.plot(kind='bar',title='Fraude Rate by type  ',color='red')
plt.ylabel('Fraud rate')
# Out:
# Text(0, 0.5, 'Fraud rate')

# %%
df['amount'].describe().astype(int)
# Out:
# count     6362620
# mean       179861
# std        603858
# min             0
# 25%         13389
# 50%         74871
# 75%        208721
# max      92445516
# Name: amount, dtype: int64

# %%
sns.histplot(np.log1p(df["amount"]), bins=100 , kde = True, color="red")
plt.title("Transaction Amount")
plt.xlabel(" log Amount")
plt.show()

# %%
sns.boxplot(data=df[df['amount']< 500000],x='isFraud',y='amount')
plt.title("Amount vs is fraud")
plt.show()

# %%
df['BalencedDiffOrig']= df['oldbalanceOrg']- df['newbalanceOrig']
df['BalencedDiffDest']= df['oldbalanceDest']- df['newbalanceDest']

# %%
(df['BalencedDiffOrig'] < 0 ).sum()
# Out:
# np.int64(1399253)

# %%
(df['BalencedDiffDest'] < 0 ).sum()
# Out:
# np.int64(2806464)

# %%
df.head(2)
# Out:
#    step     type   amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 0     1  PAYMENT  9839.64  C1231006815       170136.0       160296.36
# 1     1  PAYMENT  1864.28  C1666544295        21249.0        19384.72
#
#       nameDest  oldbalanceDest  newbalanceDest  isFraud  isFlaggedFraud  \
# 0  M1979787155             0.0             0.0        0               0
# 1  M2044282225             0.0             0.0        0               0
#
#    BalencedDiffOrig  BalencedDiffDest
# 0           9839.64               0.0
# 1           1864.28               0.0

# %%
Fraud_by_step= df[df['isFraud'] == 1]['step'].value_counts().sort_index()
plt.plot(Fraud_by_step.value , Fraud_by_step.index ,label='raud_by_step') 
plt.xlabel('Step')
plt.ylabel('Frauds number')
plt.title('Fraud by step')
plt.grid(True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/Downloads/Fraud_detection/.venv/lib/python3.12/site-packages/pandas/core/indexes/base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
# --> 168 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/index.pyx:197, in pandas._libs.index.IndexEngine.get_loc()
# --> 197 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/hashtable_class_helper.pxi:7668, in pandas._libs.hashtable.PyObjectHashTable.get_item()
# -> 7668 'Could not get source, probably due dynamically evaluated source code.'
#
# ...

# %%
df.head()
# Out:
#        type    amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 0   PAYMENT   9839.64  C1231006815       170136.0       160296.36
# 1   PAYMENT   1864.28  C1666544295        21249.0        19384.72
# 2  TRANSFER    181.00  C1305486145          181.0            0.00
# 3  CASH_OUT    181.00   C840083671          181.0            0.00
# 4   PAYMENT  11668.14  C2048537720        41554.0        29885.86
#
#       nameDest  oldbalanceDest  newbalanceDest  isFraud  isFlaggedFraud  \
# 0  M1979787155             0.0             0.0        0               0
# 1  M2044282225             0.0             0.0        0               0
# 2   C553264065             0.0             0.0        1               0
# 3    C38997010         21182.0             0.0        1               0
# 4  M1230701703             0.0             0.0        0               0
#
#    BalencedDiffOrig  BalencedDiffDest
# 0           9839.64               0.0
# 1           1864.28               0.0
# ...

# %%
top_senders= df['nameOrig'].value_counts().head(10)

# %%
top_senders
# Out:
# nameOrig
# C2098525306    3
# C400299098     3
# C1999539787    3
# C1065307291    3
# C545315117     3
# C1976208114    3
# C1784010646    3
# C1530544995    3
# C1902386530    3
# C1677795071    3
# Name: count, dtype: int64

# %%
top_receivers= df['nameDest'].value_counts().head(10)

# %%
top_receivers
# Out:
# nameDest
# C1286084959    113
# C985934102     109
# C665576141     105
# C2083562754    102
# C248609774     101
# C1590550415    101
# C451111351      99
# C1789550256     99
# C1360767589     98
# C1023714065     97
# Name: count, dtype: int64

# %%
fraud_costumers= df[df['isFraud']==1]['nameOrig'].value_counts().head(10)

# %%
fraud_costumers
# Out:
# nameOrig
# C1305486145    1
# C840083671     1
# C1420196421    1
# C2101527076    1
# C137533655     1
# C1118430673    1
# C749981943     1
# C1334405552    1
# C467632528     1
# C1364127192    1
# Name: count, dtype: int64

# %%
fraud_types = df[df['type'].isin(['TRANSFER','CASH_OUT'])]

# %%
fraud_types['type'].value_counts()
# Out:
# type
# CASH_OUT    2237500
# TRANSFER     532909
# Name: count, dtype: int64

# %%
sns.countplot(data=fraud_types,x='type',hue='isFraud')
plt.title('fraud distribution in transfer and cash out')
plt.show()

# %%
corr = df[['amount','oldbalanceOrg','newbalanceOrig','oldbalanceDest','newbalanceDest','isFraud']].corr()

# %%
corr
# Out:
#                   amount  oldbalanceOrg  newbalanceOrig  oldbalanceDest  \
# amount          1.000000      -0.002762       -0.007861        0.294137
# oldbalanceOrg  -0.002762       1.000000        0.998803        0.066243
# newbalanceOrig -0.007861       0.998803        1.000000        0.067812
# oldbalanceDest  0.294137       0.066243        0.067812        1.000000
# newbalanceDest  0.459304       0.042029        0.041837        0.976569
# isFraud         0.076688       0.010154       -0.008148       -0.005885
#
#                 newbalanceDest   isFraud
# amount                0.459304  0.076688
# oldbalanceOrg         0.042029  0.010154
# newbalanceOrig        0.041837 -0.008148
# oldbalanceDest        0.976569 -0.005885
# newbalanceDest        1.000000  0.000535
# isFraud               0.000535  1.000000

# %%
sns.heatmap(corr, annot=True , cmap='coolwarm', fmt='.2f')
plt.title('Correlation Matirx')
plt.show()

# %%
zero_after_transfer = df [
    (df['oldbalanceOrg'] > 0 )&
    (df['newbalanceOrig'] == 0) &
    (df['type'].isin(['TRANSFER','CASH_OUT']))
]

# %%
zero_after_transfer
# Out:
#              type      amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 2        TRANSFER      181.00  C1305486145         181.00             0.0
# 3        CASH_OUT      181.00   C840083671         181.00             0.0
# 15       CASH_OUT   229133.94   C905080434       15325.00             0.0
# 19       TRANSFER   215310.30  C1670993182         705.00             0.0
# 24       TRANSFER   311685.89  C1984094095       10835.00             0.0
# ...           ...         ...          ...            ...             ...
# 6362615  CASH_OUT   339682.13   C786484425      339682.13             0.0
# 6362616  TRANSFER  6311409.28  C1529008245     6311409.28             0.0
# 6362617  CASH_OUT  6311409.28  C1162922333     6311409.28             0.0
# 6362618  TRANSFER   850002.52  C1685995037      850002.52             0.0
# 6362619  CASH_OUT   850002.52  C1280323807      850002.52             0.0
#
#             nameDest  oldbalanceDest  newbalanceDest  isFraud  isFlaggedFraud  \
# ...

# %%
zero_after_transfer.head()
# Out:
#         type     amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 2   TRANSFER     181.00  C1305486145          181.0             0.0
# 3   CASH_OUT     181.00   C840083671          181.0             0.0
# 15  CASH_OUT  229133.94   C905080434        15325.0             0.0
# 19  TRANSFER  215310.30  C1670993182          705.0             0.0
# 24  TRANSFER  311685.89  C1984094095        10835.0             0.0
#
#        nameDest  oldbalanceDest  newbalanceDest  isFraud  isFlaggedFraud  \
# 2    C553264065             0.0            0.00        1               0
# 3     C38997010         21182.0            0.00        1               0
# 15   C476402209          5083.0        51513.44        0               0
# 19  C1100439041         22425.0            0.00        0               0
# 24   C932583850          6267.0      2719172.89        0               0
#
#     BalencedDiffOrig  BalencedDiffDest
# 2              181.0              0.00
# ...

# %%
df['isFraud'].value_counts()
# Out:
# isFraud
# 0    6354407
# 1       8213
# Name: count, dtype: int64

# %%
df.to_csv('clean_dataset.csv',index=False)
